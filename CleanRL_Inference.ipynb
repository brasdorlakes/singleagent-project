# %%
#This script will take the saved model from the CleanRL scripts and use it for inference so that we can compare
#To our baseline algorithm

# %%
#This script was initially made with ChatGPT and then modified for our own purposes


import torch
import gymnasium as gym
import numpy as np
from Single_ag_Environment import SingleSatelliteEnv
from cleanrl.cleanrl.c51 import QNetwork
# Import the same policy class used in the CleanRL script
env = SingleSatelliteEnv()
# Create agent (must match training architecture!)
Testing_seed_Configuration=[5,6,7,8,9,10]
num_of_test_episodes=10
import gymnasium as gym

envs = gym.vector.SyncVectorEnv([
    lambda: SingleSatelliteEnv()
])
for i in range(0,5):
    for j in range(0,num_of_test_episodes):
        obs, _ = envs.reset(seed=Testing_seed_Configuration[i])
        
        model = QNetwork(envs).to("cpu")
        
        # Load trained weights
        checkpoint = torch.load("cleanrl/cleanrl/runs/SingleSatelliteEnv__c51__1__1764003257/c51.cleanrl_model")
        #print(checkpoint)
        model.load_state_dict(checkpoint["model_weights"]) #CleanRL saves weights under "model"
        #print(dir(model))
        # Inference loop
        done = False
        while not done:
            obs_tensor = torch.tensor(obs, dtype=torch.float32)
            with torch.no_grad():
                action, q_values = model.get_action(obs_tensor)
            
            obs, reward, terminated, truncated, info = envs.step(action)
            done = terminated or truncated
            
        env.close()
# Out:
# obs: [0.8  0.8  0.5  0.3  0.1  0.4  0.4  0.   0.   1.   0.23 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.5  0.2  0.6  0.1  0.7  0.6  0.4  0.8  0.2  0.4  0.66 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.8  0.8  0.5  0.3  0.1  0.4  0.4  0.   0.   1.   0.23 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.5  0.2  0.6  0.1  0.7  0.6  0.4  0.8  0.2  0.4  0.66 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.8  0.8  0.5  0.3  0.1  0.4  0.4  0.   0.   1.   0.23 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.5  0.2  0.6  0.1  0.7  0.6  0.4  0.8  0.2  0.4  0.66 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.8  0.8  0.5  0.3  0.1  0.4  0.4  0.   0.   1.   0.23 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.5  0.2  0.6  0.1  0.7  0.6  0.4  0.8  0.2  0.4  0.66 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.8  0.8  0.5  0.3  0.1  0.4  0.4  0.   0.   1.   0.23 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.5  0.2  0.6  0.1  0.7  0.6  0.4  0.8  0.2  0.4  0.66 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.8  0.8  0.5  0.3  0.1  0.4  0.4  0.   0.   1.   0.23 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.5  0.2  0.6  0.1  0.7  0.6  0.4  0.8  0.2  0.4  0.66 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.8  0.8  0.5  0.3  0.1  0.4  0.4  0.   0.   1.   0.23 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.5  0.2  0.6  0.1  0.7  0.6  0.4  0.8  0.2  0.4  0.66 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.8  0.8  0.5  0.3  0.1  0.4  0.4  0.   0.   1.   0.23 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.5  0.2  0.6  0.1  0.7  0.6  0.4  0.8  0.2  0.4  0.66 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.8  0.8  0.5  0.3  0.1  0.4  0.4  0.   0.   1.   0.23 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.5  0.2  0.6  0.1  0.7  0.6  0.4  0.8  0.2  0.4  0.66 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.8  0.8  0.5  0.3  0.1  0.4  0.4  0.   0.   1.   0.23 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.5  0.2  0.6  0.1  0.7  0.6  0.4  0.8  0.2  0.4  0.66 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.5  0.3  0.4  0.4  1.   0.6  0.7  0.3  0.7  0.1  0.63 0.  ]
# dtype: float32
# shape: (12,)
# /tmp/ipykernel_222845/563458359.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.
0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.6  0.6  0.7  1.   0.7  0.5  1.   0.1  1.   0.5  0.51 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.9  0.3  0.6  0.8  0.7  0.9  0.9  0.9  0.   0.4  0.76 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.6  0.6  0.7  1.   0.7  0.5  1.   0.1  1.   0.5  0.51 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.9  0.3  0.6  0.8  0.7  0.9  0.9  0.9  0.   0.4  0.76 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.6  0.6  0.7  1.   0.7  0.5  1.   0.1  1.   0.5  0.51 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.9  0.3  0.6  0.8  0.7  0.9  0.9  0.9  0.   0.4  0.76 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.6  0.6  0.7  1.   0.7  0.5  1.   0.1  1.   0.5  0.51 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.9  0.3  0.6  0.8  0.7  0.9  0.9  0.9  0.   0.4  0.76 0.  ]
# dtype: float32
# shape: (12,)
# obs: [0.6  0.6  0.7  1.   0.7  0.5  1.   0.1  1.   0.5  0.51 0.  ]
# dtype: float32
# shape: (12,)

# %%
#DQN Inference
from cleanrl.cleanrl.dqn import QNetwork
# Import the same policy class used in the CleanRL script
env = SingleSatelliteEnv()
# Create agent (must match training architecture!)
Testing_seed_Configuration=[5,6,7,8,9,10]
num_of_test_episodes=10
import gymnasium as gym

envs = gym.vector.SyncVectorEnv([
    lambda: SingleSatelliteEnv()
])
for i in range(0,5):
    for j in range(0,num_of_test_episodes):
        obs, _ = envs.reset(seed=Testing_seed_Configuration[i])
        
        model = QNetwork(envs).to("cpu")
        
        # Load trained weights
        checkpoint = torch.load("cleanrl/cleanrl/runs/SingleSatelliteEnv__dqn__1__1764008081/dqn.cleanrl_model")
        print(checkpoint)
        model.load_state_dict(checkpoint) #CleanRL saves weights under "model"
        #print(dir(model))
        # Inference loop
        done = False
        while not done:
            obs_tensor = torch.tensor(obs, dtype=torch.float32)
            with torch.no_grad():
                q_values = model(torch.Tensor(obs).to("cpu"))
                actions = torch.argmax(q_values, dim=1).cpu().numpy()
            
            obs, reward, terminated, truncated, info = envs.step(action)
            done = terminated or truncated
            
        env.close()
# Out:
# obs: [0.8  0.8  0.5  0.3  0.1  0.4  0.4  0.   0.   1.   0.23 0.  ]
# dtype: float32
# shape: (12,)
# OrderedDict([('network.0.weight', tensor([[-0.1244,  0.0471, -0.1196,  ..., -0.1014, -0.8755, -0.2553],
#         [ 0.0503, -0.0715, -0.0695,  ..., -0.1873, -0.9932, -0.0143],
#         [-0.1739, -0.0585,  0.0763,  ..., -0.1993, -1.2056, -0.2727],
#         ...,
#         [-0.2983, -0.2687,  0.1691,  ..., -0.2887, -0.9147, -0.0377],
#         [ 0.0428,  0.1223,  0.1556,  ...,  0.0498, -0.1585,  0.1465],
#         [ 0.2834,  0.4070,  0.0549,  ..., -0.0570, -0.0278, -0.2581]])), ('network.0.bias', tensor([ 0.4369,  0.4977,  0.4244, -0.4164, -0.4944,  0.6289,  0.3012,  0.3491,
#         -0.4047,  0.2626,  0.4191,  0.5224,  0.5698,  0.4048,  0.2788,  0.3659,
#          0.5384, -0.4883, -0.2512, -0.0527, -0.0456,  0.2596,  0.4920,  0.5679,
#         -0.3577,  0.1479,  0.1162,  0.1820,  0.1912, -0.0608,  0.2153, -0.1611,
#          0.5813,  0.3427,  0.3467,  0.1297,  0.3358, -0.3879, -0.0626,  0.3811,
#          -5.2316e-02,  1.7206e-01,  2.4342e-02,  8.2008e-01,  6.2669e-02,
#          -3.4334e-01, -4.6602e-01,  1.5838e-01, -6.1053e-03,  2.0245e-01,
#           1.7725e-01, -1.7004e-01,  2.2522e-01,  7.9246e-01, -7.6439e-02,
#           9.1546e-02,  7.2402e-02,  1.2847e-02, -4.3083e-02,  2.5211e-01,
#           1.5386e+00,  1.6999e+00, -4.7305e-02,  6.3539e-01,  6.3076e-01,
#          -6.8008e-03,  7.7476e-01,  2.2098e-02,  8.3850e-02,  3.5163e-01,
#           1.7132e-02,  2.0691e-02,  8.9563e-01, -4.6686e-01,  5.9878e-02,
#           3.3911e-02, -9.6448e-02, -9.8734e-02,  2.1226e-01,  2.0253e+00,
#           1.3287e-02,  1.3980e+00,  4.6714e-01,  5.2799e-01,  1.2798e-01,
#           1.7622e-01, -3.0988e-01, -7.0313e-02,  1.7138e-01,  7.7965e-02,
#           5.4232e-01, -4.6463e-02, -5.6435e-02,  3.5678e-02],
#         [ 1.2777e+00,  5.9631e-01, -3.7646e-02,  2.9901e-01,  2.0536e-01,
#           2.5594e-01,  5.3775e-02,  9.0919e-02, -7.2663e-02,  3.0344e-01,
#           3.1978e-01, -1.5031e+00, -8.3125e-01,  3.0391e-01, -6.0665e-02,
#           2.8187e-01, -8.2163e-01,  2.7626e-01,  7.0028e-02, -5.1463e-01,
#          -4.7923e-02,  3.2645e-01, -4.9127e-02,  3.3077e-01,  8.2847e-01,
#          -1.6878e-02,  3.8048e-01,  7.9603e-01, -3.7686e-01,  1.3106e+00,
#          -9.3881e-02,  3.0432e-01,  3.3847e-01,  7.8702e-01,  3.2513e-01,
#          -4.3726e-01, -3.3242e-01,  2.5712e-01, -4.9711e-02,  2.3132e-01,
#           3.2563e-01, -3.9696e-01,  2.9573e-01,  1.1726e-01, -4.7855e-01,
#          -7.6518e-02,  3.7699e-02, -1.2455e-02, -7.8859e-02, -1.6146e-01,
#           7.3984e-01,  8.3606e-01, -3.5598e-03,  1.3108e+00,  1.4410e+00,
#          -2.1388e-02,  1.1970e+00, -1.4974e-03, -4.2342e-01,  2.4265e-01,
#           7.9597e-02, -1.0367e-01,  1.3472e+00, -4.3210e-01,  3.2340e-01,
#           1.2375e+00, -4.0465e-01, -4.0405e-01,  3.4579e-01, -4.6961e-01,
#           3.1952e-01,  1.0400e+00,  1.0485e+00,  9.0702e-01,  3.1199e-01,
#           3.0230e-01, -3.5497e-01, -7.0141e-02, -4.9885e-01,  6.4036e-02,
#           1.1618e+00, -9.3774e-02,  3.8117e-01,  2.9633e-01]])), ('network.4.bias', tensor([0.2591, 0.1501]))])
# /tmp/ipykernel_222845/665169169.py:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load("cleanrl/cleanrl/runs/SingleSatelliteEnv__dqn__1__1764008081/dqn.cleanrl_model")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 29
#      27 obs_tensor = torch.tensor(obs, dtype=torch.float32)
#      28 with torch.no_grad():
# ---> 29     q_values = model(torch.Tensor(obs).to(cpu))
#      30     actions = torch.argmax(q_values, dim=1).cpu().numpy()
#      32 obs, reward, terminated, truncated, info = envs.step(action)
#
# NameError: name 'cpu' is not defined

# %%
#PPO Inference
#Used ChatGPT to make the initial template and for some debugging
